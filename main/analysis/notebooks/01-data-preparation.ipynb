# %%
# cell 1
import pandas as pd
import matplotlib.pyplot as plt

# Đọc dữ liệu từ results/
alloc = pd.read_csv('../results/latest/allocation.csv')
perf = pd.read_json('../results/latest/latency_p95.json')

# %%
# cell 2: hiển thị thống kê cơ bản
alloc.describe()
